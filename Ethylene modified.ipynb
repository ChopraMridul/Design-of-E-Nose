# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
os.listdir()
# Out:
# ['176_Et_M_CO_n',
#  '057_Et_n_Me_H',
#  '036_Et_L_CO_H',
#  '119_Et_M_Me_H',
#  '023_Et_H_Me_L',
#  '018_Et_L_CO_M',
#  '159_Et_M_Me_M',
#  '074_Et_H_CO_L',
#  '133_Et_L_Me_H',
#  'Carbon Monoxide.ipynb',
#  '027_Et_M_Me_M',
#  '167_Et_H_Me_n',
#  '089_Et_H_Me_L',
#  '166_Et_H_CO_H',
#  '165_Et_L_Me_H',
#  '090_Et_n_CO_M',
#  '034_Et_H_CO_H',
#  '035_Et_H_Me_n',
#  '060_Et_H_CO_M',
#  '126_Et_H_CO_M',
#  'Untitled1.ipynb',
#  '067_Et_L_Me_H',
#  '061_Et_M_Me_n',
#  '127_Et_M_Me_n',
#  '125_Et_M_Me_M',
#  '008_Et_H_CO_L',
#  '.DS_Store',
#  'New_data',
#  '173_Et_M_Me_L',
#  '032_Et_H_CO_n',
#  '096_Et_n_CO_L',
#  '020_Et_n_CO_H.csv',
#  '071_Et_L_Me_M',
#  '011_Et_n_Me_L',
#  '137_Et_L_Me_M',
#  '156_Et_n_CO_M',
#  '065_Et_H_Me_H',
#  '143_Et_n_Me_L',
#  '121_Et_H_Me_L',
#  '064_Et_L_CO_L',
#  '163_Et_H_Me_M',
#  '058_Et_M_CO_H',
#  'Ethylene modified.ipynb',
#  '031_Et_H_Me_M',
#  '115_Et_n_Me_M',
#  '108_Et_M_CO_L',
#  '098_Et_H_CO_n',
#  'Untitled.ipynb',
#  '039_Et_L_Me_L',
# ...

# %%
a1 = pd.read_csv("000_Et_H_CO_n")
a1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
a1["Ethylene"] = 3
a1["Carbon Monoxide"] = 0
a1["Methane"] = -1
a1["conc_eth"] = 96
a1["conc_co"] = 0
a1["conc_me"] = 0

b1 = pd.read_csv("010_Et_M_CO_n")
b1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
b1["Ethylene"] = 2
b1["Carbon Monoxide"] = 0
b1["Methane"] = -1
b1["conc_eth"] = 46
b1["conc_co"] = 0
b1["conc_me"] = 0

c1 = pd.read_csv("014_Et_L_CO_n")
c1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
c1["Ethylene"] = 1
c1["Carbon Monoxide"] = 0
c1["Methane"] = -1
c1["conc_eth"] = 31
c1["conc_co"] = 0
c1["conc_me"] = 0

d1 = pd.read_csv("030_Et_n_CO_L")
d1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
d1["Ethylene"] = 0
d1["Carbon Monoxide"] = 1
d1["Methane"] = -1
d1["conc_eth"] = 0
d1["conc_co"] = 270
d1["conc_me"] = 0

e1 = pd.read_csv("024_Et_n_CO_M")
e1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
e1["Ethylene"] = 0
e1["Carbon Monoxide"] = 2
e1["Methane"] = -1
e1["conc_eth"] = 0
e1["conc_co"] = 397
e1["conc_me"] = 0

f1 = pd.read_csv("012_Et_n_CO_H.csv")
f1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
f1["Ethylene"] = 0
f1["Carbon Monoxide"] = 3
f1["Methane"] = -1
f1["conc_eth"] = 0
f1["conc_co"] = 460
f1["conc_me"] = 0

g1 = pd.read_csv("002_Et_H_CO_H")
g1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
g1["Ethylene"] = 3
g1["Carbon Monoxide"] = 3
g1["Methane"] = -1
g1["conc_eth"] = 96
g1["conc_co"] = 460
g1["conc_me"] = 0

h1 = pd.read_csv("016_Et_L_CO_L")
h1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
h1["Ethylene"] = 1
h1["Carbon Monoxide"] = 1
h1["Methane"] = -1
h1["conc_eth"] = 31
h1["conc_co"] = 270
h1["conc_me"] = 0

i1 = pd.read_csv("022_Et_M_CO_L")
i1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
i1["Ethylene"] = 2
i1["Carbon Monoxide"] = 1
i1["Methane"] = -1
i1["conc_eth"] = 46
i1["conc_co"] = 270
i1["conc_me"] = 0

j1 = pd.read_csv("008_Et_H_CO_L")
j1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
j1["Ethylene"] = 3
j1["Carbon Monoxide"] = 1
j1["Methane"] = -1
j1["conc_eth"] = 96
j1["conc_co"] = 270
j1["conc_me"] = 0

k1 = pd.read_csv("018_Et_L_CO_M")
k1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
k1["Ethylene"] = 1
k1["Carbon Monoxide"] = 2
k1["Methane"] = -1
k1["conc_eth"] = 31
k1["conc_co"] = 397
k1["conc_me"] = 0

l1 = pd.read_csv("004_Et_L_CO_H")
l1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
l1["Ethylene"] = 1
l1["Carbon Monoxide"] = 3
l1["Methane"] = -1
l1["conc_eth"] = 31
l1["conc_co"] = 460
l1["conc_me"] = 0

m1 = pd.read_csv("006_Et_M_CO_M")
m1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
m1["Ethylene"] = 2
m1["Carbon Monoxide"] = 2
m1["Methane"] = -1
m1["conc_eth"] = 46
m1["conc_co"] = 397
m1["conc_me"] = 0

n1 = pd.read_csv("026_Et_M_CO_H")
n1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
n1["Ethylene"] = 2
n1["Carbon Monoxide"] = 3
n1["Methane"] = -1
n1["conc_eth"] = 46
n1["conc_co"] = 460
n1["conc_me"] = 0

o1 = pd.read_csv("028_Et_H_CO_M")
o1.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
o1["Ethylene"] = 3
o1["Carbon Monoxide"] = 2
o1["Methane"] = -1
o1["conc_eth"] = 96
o1["conc_co"] = 397
o1["conc_me"] = 0



concentration1 = a1.append([b1,c1,d1,e1,f1,g1,h1,i1,j1,k1,l1,m1,n1,o1])
concentration1.tail()
# Out:
#       Time (s)  Temperature (oC)   Relative_Humidity  TGS2600  TGS2602_1  \
# 2964    299.50             22.46                41.4    363.0      290.0
# 2965    299.60             22.46                41.4    362.0      289.0
# 2966    299.71             22.46                41.4    363.0      289.0
# 2967    299.80             22.46                41.4    362.0      290.0
# 2968    299.90             22.46                41.4    363.0      289.0
#
#       TGS2602_2  TGS2620_1  TGS2612  TGS2620_2  TGS2611  TGS2610  Ethylene  \
# 2964      563.0      708.0    695.0      874.0    742.0    844.0         3
# 2965      562.0      708.0    695.0      874.0    742.0    843.0         3
# 2966      563.0      707.0    695.0      873.0    742.0    843.0         3
# 2967      562.0      707.0    695.0      873.0    741.0    843.0         3
# 2968      562.0      707.0    694.0      872.0    742.0    843.0         3
#
#       Carbon Monoxide  Methane  conc_eth  conc_co  conc_me
# ...

# %%
a2 = pd.read_csv("003_Et_H_Me_n")
a2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
a2["Ethylene"] = 3
a2["Carbon Monoxide"] = -1
a2["Methane"] = 0
a2["conc_eth"] = 96
a2["conc_co"] = 0
a2["conc_me"] = 0

b2 = pd.read_csv("029_Et_M_Me_n")
b2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
b2["Ethylene"] = 2
b2["Carbon Monoxide"] = -1
b2["Methane"] = 0
b2["conc_eth"] = 46
b2["conc_co"] = 0
b2["conc_me"] = 0

c2 = pd.read_csv("013_Et_L_Me_n")
c2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
c2["Ethylene"] = 1
c2["Carbon Monoxide"] = -1
c2["Methane"] = 0
c2["conc_eth"] = 31
c2["conc_co"] = 0
c2["conc_me"] = 0

d2 = pd.read_csv("011_Et_n_Me_L")
d2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
d2["Ethylene"] = 0
d2["Carbon Monoxide"] = -1
d2["Methane"] = 1
d2["conc_eth"] = 0
d2["conc_co"] = 0
d2["conc_me"] = 51

e2 = pd.read_csv("015_Et_n_Me_M")
e2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
e2["Ethylene"] = 0
e2["Carbon Monoxide"] =-1
e2["Methane"] = 2
e2["conc_eth"] = 0
e2["conc_co"] = 0
e2["conc_me"] = 115

f2 = pd.read_csv("025_Et_n_Me_H")
f2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
f2["Ethylene"] = 0
f2["Carbon Monoxide"] = -1
f2["Methane"] = 2
f2["conc_eth"] = 0
f2["conc_co"] = 0
f2["conc_me"] = 131

g2 = pd.read_csv("017_Et_H_Me_H")
g2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
g2["Ethylene"] = 3
g2["Carbon Monoxide"] = -1
g2["Methane"] = 3
g2["conc_eth"] = 96
g2["conc_co"] = 0
g2["conc_me"] = 131

h2 = pd.read_csv("007_Et_L_Me_L")
h2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
h2["Ethylene"] = 1
h2["Carbon Monoxide"] = -1
h2["Methane"] = 1
h2["conc_eth"] = 31
h2["conc_co"] = 0
h2["conc_me"] = 51

i2 = pd.read_csv("009_Et_M_Me_L")
i2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
i2["Ethylene"] = 2
i2["Carbon Monoxide"] = -1
i2["Methane"] = 1
i2["conc_eth"] = 46
i2["conc_co"] = 0
i2["conc_me"] = 51

j2 = pd.read_csv("023_Et_H_Me_L")
j2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
j2["Ethylene"] = 3
j2["Carbon Monoxide"] = -1
j2["Methane"] = 1
j2["conc_eth"] = 96
j2["conc_co"] = 0
j2["conc_me"] = 51

k2 = pd.read_csv("005_Et_L_Me_M")
k2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
k2["Ethylene"] = 1
k2["Carbon Monoxide"] = -1
k2["Methane"] = 2
k2["conc_eth"] = 31
k2["conc_co"] = 0
k2["conc_me"] = 115

l2 = pd.read_csv("001_Et_L_Me_H")
l2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
l2["Ethylene"] = 1
l2["Carbon Monoxide"] = -1
l2["Methane"] = 3
l2["conc_eth"] = 31
l2["conc_co"] = 0
l2["conc_me"] = 131

m2 = pd.read_csv("027_Et_M_Me_M")
m2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
m2["Ethylene"] = 2
m2["Carbon Monoxide"] = -1
m2["Methane"] = 2
m2["conc_eth"] = 46
m2["conc_co"] = 0
m2["conc_me"] = 115

n2 = pd.read_csv("019_Et_M_Me_H")
n2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
n2["Ethylene"] = 2
n2["Carbon Monoxide"] = -1
n2["Methane"] = 3
n2["conc_eth"] = 46
n2["conc_co"] = 0
n2["conc_me"] = 131

o2 = pd.read_csv("031_Et_H_Me_M")
o2.columns = ['Time (s)', 'Temperature (oC)',' Relative_Humidity','TGS2600', 'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2', 'TGS2611', 'TGS2610']
o2["Ethylene"] = 3
o2["Carbon Monoxide"] = -1
o2["Methane"] = 2
o2["conc_eth"] = 96
o2["conc_co"] = 0
o2["conc_me"] = 115



concentration2 = a2.append([b2,c2,d2,e2,f2,g2,h2,i2,j2,k2,l2,m2,n2,o2])
concentration2.tail()
# Out:
#       Time (s)  Temperature (oC)   Relative_Humidity  TGS2600  TGS2602_1  \
# 2964    299.51             21.38               44.33    381.0      333.0
# 2965    299.61             21.38               44.33    381.0      333.0
# 2966    299.71             21.38               44.33    380.0      332.0
# 2967    299.81             21.38               44.33    381.0      333.0
# 2968    299.91             21.38               44.33    382.0      333.0
#
#       TGS2602_2  TGS2620_1  TGS2612  TGS2620_2  TGS2611  TGS2610  Ethylene  \
# 2964      617.0      695.0    647.0      804.0    694.0    789.0         3
# 2965      616.0      696.0    647.0      804.0    694.0    789.0         3
# 2966      617.0      695.0    647.0      804.0    693.0    789.0         3
# 2967      616.0      695.0    646.0      803.0    694.0    789.0         3
# 2968      616.0      695.0    646.0      804.0    693.0    789.0         3
#
#       Carbon Monoxide  Methane  conc_eth  conc_co  conc_me
# ...

# %%
concentration = concentration1.append(concentration2)
concentration.tail()
# Out:
#       Time (s)  Temperature (oC)   Relative_Humidity  TGS2600  TGS2602_1  \
# 2964    299.51             21.38               44.33    381.0      333.0
# 2965    299.61             21.38               44.33    381.0      333.0
# 2966    299.71             21.38               44.33    380.0      332.0
# 2967    299.81             21.38               44.33    381.0      333.0
# 2968    299.91             21.38               44.33    382.0      333.0
#
#       TGS2602_2  TGS2620_1  TGS2612  TGS2620_2  TGS2611  TGS2610  Ethylene  \
# 2964      617.0      695.0    647.0      804.0    694.0    789.0         3
# 2965      616.0      696.0    647.0      804.0    694.0    789.0         3
# 2966      617.0      695.0    647.0      804.0    693.0    789.0         3
# 2967      616.0      695.0    646.0      803.0    694.0    789.0         3
# 2968      616.0      695.0    646.0      804.0    693.0    789.0         3
#
#       Carbon Monoxide  Methane  conc_eth  conc_co  conc_me
# ...

# %%
concentration.shape
# Out:
# (89070, 17)

# %%
concentration.describe()
# Out:
#            Time (s)  Temperature (oC)   Relative_Humidity       TGS2600  \
# count  89070.000000      89070.000000        89070.000000  89070.000000
# mean     151.502731         21.967761           42.688139    401.894611
# std       85.708603          0.484393            2.193671     48.606619
# min        3.090000         21.360000           39.790000    331.000000
# 25%       77.300000         21.460000           40.530000    354.000000
# 50%      151.500000         22.040000           42.865000    398.000000
# 75%      225.710000         22.450000           44.840000    443.000000
# max      300.000000         22.480000           45.410000    526.000000
#
#           TGS2602_1     TGS2602_2     TGS2620_1       TGS2612     TGS2620_2  \
# count  89070.000000  89070.000000  89070.000000  89070.000000  89070.000000
# mean     324.190816    639.477433    701.516302    703.529235    869.569249
# std       36.526245     80.559318    100.288771    107.419793    133.889956
# ...

# %% [markdown]
# # Data Visualization

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
concentration.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ["Ethylene", "conc_eth", "Time (s)","TGS2602_2"]
scatter_matrix(concentration[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a271f2828>,
# ...
#       dtype=object)

# %%
corr_matrix = concentration.corr()
corr_matrix['Ethylene'].sort_values(ascending=False)
# Out:
# Ethylene              1.000000
# conc_eth              0.974294
# TGS2610               0.491100
# TGS2611               0.479394
# TGS2612               0.477511
# TGS2620_2             0.448833
# TGS2600               0.367082
# TGS2602_2             0.275101
# TGS2602_1             0.187379
# TGS2620_1             0.112301
# Time (s)              0.000002
#  Relative_Humidity   -0.000241
# Temperature (oC)     -0.009949
# Methane              -0.016873
# Carbon Monoxide      -0.048947
# conc_me              -0.068720
# conc_co              -0.072743
# Name: Ethylene, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
concentration.columns
# Out:
# Index(['Time (s)', 'Temperature (oC)', ' Relative_Humidity', 'TGS2600',
#        'TGS2602_1', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2',
#        'TGS2611', 'TGS2610', 'Ethylene', 'Carbon Monoxide', 'Methane',
#        'conc_eth', 'conc_co', 'conc_me'],
#       dtype='object')

# %% [markdown]
# # Split Train-Test Dataset

# %%
X = concentration.drop(['Temperature (oC)', ' Relative_Humidity','Ethylene','Carbon Monoxide', 'Methane', 'Time (s)', 'conc_co', 'conc_me'], axis = 1)
y = concentration['Ethylene']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=10)

# %%
print(len(X_train), "train +", len(X_test), "test")
# Out:
# 71256 train + 17814 test

# %% [markdown]
# # Training Data Visualization

# %%
corr_matrix = X_train.corr()

# %%
corr_matrix['conc_eth'].sort_values(ascending=False)
# Out:
# conc_eth     1.000000
# TGS2610      0.466277
# TGS2612      0.457508
# TGS2611      0.455436
# TGS2620_2    0.430547
# TGS2600      0.347169
# TGS2602_2    0.262991
# TGS2602_1    0.182830
# TGS2620_1    0.081798
# Name: conc_eth, dtype: float64

# %% [markdown]
# # Heat Map

# %%
import seaborn as sns
sns.heatmap(X_train.corr(), linewidths=1)

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(X_train)

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x = 'Ethylene' , data = concentration)

# %%
#df_xtr = X_train.drop(labels = ['Temperature (oC)', ' Relative_Humidity',], axis = 1)
df_train = X_train

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# # Box Plot

# %%
from matplotlib import pyplot as plt
df_bp = df_train.copy()
df_bp = concentration
for i in ['TGS2600', 'TGS2602_2', 'TGS2620_1', 'TGS2612', 'TGS2620_2','TGS2611', 'TGS2610' ]:
    plt.figure(figsize=(6,6))

    sns.boxplot(x = 'Ethylene', y = i , data = df_bp, palette='winter')

# %% [markdown]
# # Training with 4 classification models

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
classifier = LR.fit(df_train,y_train)

from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score

#K-Fold CROSS VALIDATION logestic regression

scores = cross_val_score(classifier, df_train, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.84 (+/- 0.01)

# %% [markdown]
# # Decission Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
clf = DecisionTreeClassifier(max_depth=2)

# Train Decision Tree Classifer
classifier_1 = clf.fit(df_train,y_train)
scores_1 = cross_val_score(classifier_1, df_train, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_1.mean(), scores_1.std() * 2))
# Out:
# Accuracy: 0.80 (+/- 0.00)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=10,max_depth=3)
classifier_2 = rfc.fit(df_train, y_train)
scores_2 = cross_val_score(classifier_2, df_train, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_2.mean(), scores_2.std() * 2))
# Out:
# Accuracy: 0.89 (+/- 0.17)

# %% [markdown]
# # LDA & QDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
qda = QuadraticDiscriminantAnalysis()
lda = LinearDiscriminantAnalysis() 
classifier_3 = lda.fit(df_train, y_train)
classifier_4 = qda.fit(df_train, y_train)

# %% [markdown]
# # LDA

# %%
scores_3 = cross_val_score(classifier_3, df_train, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_3.mean(), scores_3.std() * 2))
# Out:
# Accuracy: 0.54 (+/- 0.01)

# %% [markdown]
# # QDA

# %%
scores_4 = cross_val_score(classifier_4, df_train, y_train, cv=100)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_4.mean(), scores_4.std() * 2))
# Out:
# Accuracy: 0.20 (+/- 0.00)

# %% [markdown]
# # TESTING PERFORMANCE

# %% [markdown]
# # Logistic Regression

# %%
df_test = X_test
#X_test.columns
predictions_1 = LR.predict(df_test)
print(confusion_matrix(y_test,predictions_1))
print(classification_report(y_test,predictions_1))
# Out:
# [[3511    0    0    0]
#  [   0 3602 1136    0]
#  [   0 1768 2994    0]
#  [   0    0    0 4803]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3511
#            1       0.67      0.76      0.71      4738
#            2       0.72      0.63      0.67      4762
#            3       1.00      1.00      1.00      4803
#
#    micro avg       0.84      0.84      0.84     17814
#    macro avg       0.85      0.85      0.85     17814
# weighted avg       0.84      0.84      0.84     17814

# %% [markdown]
# # Random Forest

# %%
predictions_2 = classifier_2.predict(df_test)
print(confusion_matrix(y_test,predictions_2))
print(classification_report(y_test,predictions_2))
# Out:
# [[3499   12    0    0]
#  [  46 4641   51    0]
#  [ 162 1805 2795    0]
#  [   0   15  365 4423]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      3511
#            1       0.72      0.98      0.83      4738
#            2       0.87      0.59      0.70      4762
#            3       1.00      0.92      0.96      4803
#
#    micro avg       0.86      0.86      0.86     17814
#    macro avg       0.88      0.87      0.86     17814
# weighted avg       0.88      0.86      0.86     17814

# %% [markdown]
# # Decission Tree

# %%
predictions_3 = clf.predict(df_test)
print(confusion_matrix(y_test,predictions_3))
print(classification_report(y_test,predictions_3))
# Out:
# [[   0 3511    0    0]
#  [   0 4738    0    0]
#  [   0    0 4762    0]
#  [   0    0    0 4803]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      3511
#            1       0.57      1.00      0.73      4738
#            2       1.00      1.00      1.00      4762
#            3       1.00      1.00      1.00      4803
#
#    micro avg       0.80      0.80      0.80     17814
#    macro avg       0.64      0.75      0.68     17814
# weighted avg       0.69      0.80      0.73     17814

# %% [markdown]
# # LDA

# %%
predictions_4 = lda.predict(df_test)
print(confusion_matrix(y_test,predictions_4))
print(classification_report(y_test,predictions_4))
# Out:
# [[2209 1086  208    8]
#  [ 632 3150  545  411]
#  [ 193 1457 1664 1448]
#  [ 215 1820  326 2442]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.65      3511
#            1       0.42      0.66      0.51      4738
#            2       0.61      0.35      0.44      4762
#            3       0.57      0.51      0.54      4803
#
#    micro avg       0.53      0.53      0.53     17814
#    macro avg       0.57      0.54      0.54     17814
# weighted avg       0.56      0.53      0.53     17814

# %% [markdown]
# # QDA

# %%
predictions_5 = qda.predict(df_test)
print(confusion_matrix(y_test,predictions_5))
print(classification_report(y_test,predictions_5))
# Out:
# [[3511    0    0    0]
#  [4738    0    0    0]
#  [4762    0    0    0]
#  [4803    0    0    0]]
#               precision    recall  f1-score   support
#
#            0       0.20      1.00      0.33      3511
#            1       0.00      0.00      0.00      4738
#            2       0.00      0.00      0.00      4762
#            3       0.00      0.00      0.00      4803
#
#    micro avg       0.20      0.20      0.20     17814
#    macro avg       0.05      0.25      0.08     17814
# weighted avg       0.04      0.20      0.06     17814

# %% [markdown]
# # Fine Tuning and Optimization

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

X = df_train.values
X = scale(X)
pca = PCA(n_components=9)
pca.fit(X)

#The amount of variance that each PC explains
var= pca.explained_variance_ratio_

#Cumulative Variance explains
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

print (var1)
# Out:
# [ 70.68  84.36  94.69  99.04  99.52  99.81  99.98 100.   100.01]

# %%
plt.plot(var1)

# %%
pca = PCA(n_components=3)
pca.fit(X)
X1=pca.fit_transform(X)

print(X1)
# Out:
# [[-2.39696517 -0.68555867 -1.54022193]
#  [-3.04656418 -0.80799605 -0.54514204]
#  [ 3.69166858 -0.95732829  1.59618872]
#  ...
#  [-3.11529026 -0.44246972  0.68506761]
#  [-2.92097688 -0.18252892 -0.23379706]
#  [-2.56247325 -0.11701558 -0.4228962 ]]

# %% [markdown]
# # Logistic Regression

# %%
classifier_5 = LR.fit(X1,y_train)
scores_5 = cross_val_score(classifier_5, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_5.mean(), scores_5.std() * 2))
# Out:
# Accuracy: 0.81 (+/- 0.01)

# %% [markdown]
# # Decission Tree

# %%
classifier_6 = DecisionTreeClassifier(max_depth=12)

# Train Decision Tree Classifer
classifier_6 = classifier_6.fit(X1,y_train)
scores_6 = cross_val_score(classifier_6, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_6.mean(), scores_6.std() * 2))
# Out:
# Accuracy: 0.99 (+/- 0.00)

# %% [markdown]
# # Random Forest

# %%
rfc = RandomForestClassifier(n_estimators=10,max_depth=10)
classifier_7 = rfc.fit(X1,y_train)

scores_7 = cross_val_score(classifier_7, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_7.mean(), scores_7.std() * 2))
# Out:
# Accuracy: 0.99 (+/- 0.00)

# %% [markdown]
# # LDA

# %%
classifier_9 = lda.fit(X1,y_train)
scores_9 = cross_val_score(classifier_9, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_9.mean(), scores_9.std() * 2))
# Out:
# Accuracy: 0.87 (+/- 0.01)

# %% [markdown]
# # QDA

# %%
classifier_8 = qda.fit(X1,y_train)
scores_8 = cross_val_score(classifier_8, X1, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_8.mean(), scores_8.std() * 2))
# Out:
# Accuracy: 0.87 (+/- 0.01)

# %%
X_t=X_test.values
X_t = scale(X_t)
pca = PCA(n_components=9)
pca.fit(X)

#The amount of variance that each PC explains
vari= pca.explained_variance_ratio_

#Cumulative Variance explains
var2=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

print (var2)
# Out:
# [ 70.68  84.36  94.69  99.04  99.52  99.81  99.98 100.   100.01]

# %%
plt.plot(var2)

# %% [markdown]
# # Performance Tuning on Test Data

# %%
#BASED ON THE ABOVE PLOT, CONSIDERED 3 FEATURES
pca = PCA(n_components=3)
pca.fit(X_t)
X2=pca.fit_transform(X_t)

print(X2)
# Out:
# [[ 0.33991928 -1.70223305 -1.33893094]
#  [-3.54827656 -0.12208934 -0.23527221]
#  [-3.08609402 -0.78756089 -0.5198404 ]
#  ...
#  [-2.78890881 -0.13255673 -0.0445755 ]
#  [-2.42138287 -0.65444715 -1.59566924]
#  [ 4.07400968 -1.19651275  1.6083491 ]]

# %% [markdown]
# # Logistic Regression

# %%
predictions_10 = LR.predict(X2)
print(confusion_matrix(y_test,predictions_10))
print(classification_report(y_test,predictions_10))
# Out:
# [[3511    0    0    0]
#  [   0 3332 1406    0]
#  [   0 1872 2879   11]
#  [   0    0    1 4802]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3511
#            1       0.64      0.70      0.67      4738
#            2       0.67      0.60      0.64      4762
#            3       1.00      1.00      1.00      4803
#
#    micro avg       0.82      0.82      0.82     17814
#    macro avg       0.83      0.83      0.83     17814
# weighted avg       0.82      0.82      0.81     17814

# %% [markdown]
# # Decission Tree

# %%
predictions_11 = classifier_6.predict(X2)
print(confusion_matrix(y_test,predictions_11))
print(classification_report(y_test,predictions_11))
# Out:
# [[3511    0    0    0]
#  [  17 4669   52    0]
#  [   0  289 4461   12]
#  [   0    0    0 4803]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3511
#            1       0.94      0.99      0.96      4738
#            2       0.99      0.94      0.96      4762
#            3       1.00      1.00      1.00      4803
#
#    micro avg       0.98      0.98      0.98     17814
#    macro avg       0.98      0.98      0.98     17814
# weighted avg       0.98      0.98      0.98     17814

# %% [markdown]
# # Random Forest

# %%
predictions_12 = rfc.predict(X2)
print(confusion_matrix(y_test,predictions_12))
print(classification_report(y_test,predictions_12))
# Out:
# [[3511    0    0    0]
#  [   0 4675   63    0]
#  [   0  214 4536   12]
#  [   0    0    4 4799]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3511
#            1       0.96      0.99      0.97      4738
#            2       0.99      0.95      0.97      4762
#            3       1.00      1.00      1.00      4803
#
#    micro avg       0.98      0.98      0.98     17814
#    macro avg       0.98      0.98      0.98     17814
# weighted avg       0.98      0.98      0.98     17814

# %% [markdown]
# # LDA

# %%
predictions_13 = lda.predict(X2)
print(confusion_matrix(y_test,predictions_13))
print(classification_report(y_test,predictions_13))
# Out:
# [[3356  155    0    0]
#  [   0 4386  352    0]
#  [   0 1469 2957  336]
#  [   0    0    0 4803]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      3511
#            1       0.73      0.93      0.82      4738
#            2       0.89      0.62      0.73      4762
#            3       0.93      1.00      0.97      4803
#
#    micro avg       0.87      0.87      0.87     17814
#    macro avg       0.89      0.88      0.87     17814
# weighted avg       0.88      0.87      0.87     17814

# %% [markdown]
# # QDA

# %%
predictions_14 = qda.predict(X2)
print(confusion_matrix(y_test,predictions_14))
print(classification_report(y_test,predictions_14))
# Out:
# [[3416   95    0    0]
#  [   0 4388  350    0]
#  [   0 1601 2880  281]
#  [   0    0    0 4803]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99      3511
#            1       0.72      0.93      0.81      4738
#            2       0.89      0.60      0.72      4762
#            3       0.94      1.00      0.97      4803
#
#    micro avg       0.87      0.87      0.87     17814
#    macro avg       0.89      0.88      0.87     17814
# weighted avg       0.88      0.87      0.86     17814

# %% [markdown]
# # SOLVING SENSOR DRIFT PROBLEM

# %%
new_data = []
concentration.set_index('Time (s)')
for index, value in concentration.iterrows():
    if value[0] > 240:
        new_data.append(value)
df = pd.DataFrame(new_data)
df.to_csv("New_data", index=False)

# %%
Data = pd.read_csv("New_data")

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17980 entries, 0 to 17979
# Data columns (total 17 columns):
# Time (s)              17980 non-null float64
# Temperature (oC)      17980 non-null float64
#  Relative_Humidity    17980 non-null float64
# TGS2600               17980 non-null float64
# TGS2602_1             17980 non-null float64
# TGS2602_2             17980 non-null float64
# TGS2620_1             17980 non-null float64
# TGS2612               17980 non-null float64
# TGS2620_2             17980 non-null float64
# TGS2611               17980 non-null float64
# TGS2610               17980 non-null float64
# Ethylene              17980 non-null float64
# Carbon Monoxide       17980 non-null float64
# Methane               17980 non-null float64
# conc_eth              17980 non-null float64
# conc_co               17980 non-null float64
# conc_me               17980 non-null float64
# dtypes: float64(17)
# memory usage: 2.3 MB

# %%
Data.head()
# Out:
#    Time (s)  Temperature (oC)   Relative_Humidity  TGS2600  TGS2602_1  \
# 0    240.01             22.45                40.7    445.0      321.0
# 1    240.11             22.45                40.7    447.0      322.0
# 2    240.21             22.45                40.7    446.0      321.0
# 3    240.30             22.45                40.7    447.0      321.0
# 4    240.40             22.45                40.7    445.0      321.0
#
#    TGS2602_2  TGS2620_1  TGS2612  TGS2620_2  TGS2611  TGS2610  Ethylene  \
# 0      661.0      638.0    921.0     1129.0   1026.0   1121.0       3.0
# 1      661.0      639.0    921.0     1129.0   1027.0   1122.0       3.0
# 2      661.0      638.0    921.0     1129.0   1028.0   1123.0       3.0
# 3      661.0      639.0    921.0     1130.0   1028.0   1124.0       3.0
# 4      660.0      638.0    921.0     1130.0   1028.0   1124.0       3.0
#
#    Carbon Monoxide  Methane  conc_eth  conc_co  conc_me
# ...

# %%
Data.describe()
# Out:
#            Time (s)  Temperature (oC)   Relative_Humidity       TGS2600  \
# count  17980.000000      17980.000000        17980.000000  17980.000000
# mean     269.986522         21.963194           42.688664    404.812403
# std       17.301540          0.487293            2.189996     39.873750
# min      240.010000         21.360000           39.790000    347.000000
# 25%      255.000000         21.460000           40.530000    372.000000
# 50%      270.000000         22.420000           41.440000    395.000000
# 75%      284.962500         22.450000           44.840000    434.000000
# max      300.000000         22.480000           45.380000    526.000000
#
#           TGS2602_1     TGS2602_2     TGS2620_1       TGS2612     TGS2620_2  \
# count  17980.000000  17980.000000  17980.000000  17980.000000  17980.000000
# mean     328.653115    645.715684    725.952892    721.036596    897.176808
# std       34.335998     65.715494     94.746770     93.242891    115.512585
# ...

# %%
X = Data.drop(['Ethylene','Carbon Monoxide', 'Methane', 'conc_co', 'conc_me'], axis = 1)
y = Data['Ethylene']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=10)

# %%
print(len(X_train), "train +", len(X_test), "test")
# Out:
# 14384 train + 3596 test

# %%
corr_matrix = X_train.corr()

# %%
corr_matrix['Temperature (oC)'].sort_values(ascending=False)
# Out:
# Temperature (oC)      1.000000
# TGS2620_1             0.498163
# TGS2620_2             0.469989
# TGS2610               0.430242
# TGS2611               0.427941
# TGS2612               0.403890
# Time (s)              0.001979
# conc_eth             -0.006461
# TGS2600              -0.252849
# TGS2602_2            -0.259822
# TGS2602_1            -0.624271
#  Relative_Humidity   -0.975991
# Name: Temperature (oC), dtype: float64

# %% [markdown]
# # Logistic Regression

# %%
new_train = X_train.copy()

scores = cross_val_score(classifier, new_train, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.80 (+/- 0.00)

# %% [markdown]
# # Random Forest

# %%
rfc = RandomForestClassifier(n_estimators=10,max_depth=4)
classifier_2 = rfc.fit(df_train, y_train)
scores_2 = cross_val_score(classifier_2, new_train, y_train, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_2.mean(), scores_2.std() * 2))
# Out:
# Accuracy: 0.99 (+/- 0.02)
